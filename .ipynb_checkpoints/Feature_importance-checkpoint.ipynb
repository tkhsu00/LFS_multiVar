# %%
import pandas as pd
from numpy import loadtxt
import xgboost as xgb
from matplotlib import pyplot

# %%
# load data
fn = "LFS_clean.tsv"
df = pd.read_csv(fn,sep="\t")
df.head()
# Out:
#   Family_code Country        Population    Region             Development  \
# 0      Bard94     USA  Northern America  Americas  More developed regions
# 1      Bard94     USA  Northern America  Americas  More developed regions
# 2      Bard94     USA  Northern America  Americas  More developed regions
# 3       Bir16      UK   Northern Europe    Europe  More developed regions
# 4       Bir16      UK   Northern Europe    Europe  More developed regions
#
#   Class  Generations_analyzed WT_nucleotide Mutant_nucleotide WT_codon  \
# 0   LFL                   2.0           A                   G      ATG
# 1   LFL                   2.0           A                   G      ATG
# 2   LFL                   2.0           A                   G      ATG
# 3   LFS                   2.0           A                   G      TAT
# 4   LFS                   2.0           A                   G      TAT
#
#              ...            Generation Sex Germline_carrier  \
# 0            ...                   3.0   F        Confirmed
# 1            ...                   2.0   F        Confirmed
# 2            ...                   3.0   F              NaN
# 3            ...                   1.0   F        Confirmed
# 4            ...                   2.0   F        Confirmed
#
#   Mode_of_inheritance   Dead   Age Age_at_diagnosis Ref_ID  \
# 0                   M  False   NaN              6.0      1
# 1                 NaN   True  35.0             30.0      1
# 2                 NaN   True   NaN              1.0      1
# 3                 NaN   True  27.0             27.0      2
# 4                   M   True   NaN              1.0      2
#
#   Short_topo_combined Short_topo_combined_count
# 0     HEMATOP. SYSTEM                         1
# 1        CERVIX UTERI                         1
# 2       ADRENAL GLAND                         1
# 3              BREAST                         1
# 4       ADRENAL GLAND                         1
#
# [5 rows x 44 columns]

# %%
df.describe()
# Out:
#        Generations_analyzed        REVEL     BayesDel    COSMIClink  \
# count           1942.000000  1542.000000  1542.000000  1.946000e+03
# mean               2.942327     0.843647     0.425752  7.379567e+04
# std                1.141133     0.118780     0.172896  5.047241e+05
# min                1.000000     0.272000    -0.201800  6.482000e+03
# 25%                2.000000     0.754000     0.262400  1.066300e+04
# 50%                3.000000     0.896000     0.517400  1.108900e+04
# 75%                4.000000     0.927000     0.553600  4.388200e+04
# max                6.000000     0.981000     0.607100  6.904034e+06
#
#          CLINVARlink  cBioportalCount   Generation         Age  \
# count    1702.000000      2192.000000  1785.000000  623.000000
# mean   131490.653937        81.620894     2.173669   33.995185
# std    141030.220743       131.813933     0.950030   19.546259
# min     12347.000000         0.000000     1.000000    1.000000
# 25%     12374.000000         3.000000     1.000000   18.000000
# 50%    127816.000000        12.000000     2.000000   33.000000
# 75%    182970.000000       140.000000     3.000000   47.000000
# max    528263.000000       493.000000     5.000000   92.000000
#
#        Age_at_diagnosis       Ref_ID  Short_topo_combined_count
# count       2192.000000  2192.000000                2192.000000
# mean          29.247719   174.964872                   1.019161
# std           20.102686   110.555628                   0.137121
# min            0.000000     1.000000                   1.000000
# 25%           12.000000    86.000000                   1.000000
# 50%           29.000000   153.000000                   1.000000
# 75%           42.000000   265.000000                   1.000000
# max           91.000000   384.000000                   2.000000

# %%
# Number of each type of column
df.dtypes.value_counts()
# Out:
# object     32
# float64     8
# int64       3
# bool        1
# dtype: int64

# %%
# Number of unique classes in each object column
df.select_dtypes('object').apply(pd.Series.nunique, axis = 0)
# Out:
# Family_code              896
# Country                   44
# Population                16
# Region                     6
# Development                2
# Class                      6
# WT_nucleotide              7
# Mutant_nucleotide          4
# WT_codon                  54
# Mutant_codon              57
# CpG_site                   2
# Splice_site                5
# Context_coding_3          17
# WT_AA                     21
# Mutant_AA                 21
# Effect                     8
# AGVGDClass                 7
# SIFTClass                  2
# Polyphen2                  3
# TransactivationClass       4
# DNEclass                   3
# ProtDescription          244
# Hotspot                    2
# Domain_function            9
# Residue_function          15
# Individual_code         2192
# FamilyCase                50
# FamilyCase_group           6
# Sex                        2
# Germline_carrier           4
# Mode_of_inheritance        4
# Short_topo_combined       87
# dtype: int64

# %%
# Remove individul code
df = df.drop(['Individual_code'],axis=1)
df.select_dtypes('object').apply(pd.Series.nunique, axis = 0)
# Out:
# Family_code             896
# Country                  44
# Population               16
# Region                    6
# Development               2
# Class                     6
# WT_nucleotide             7
# Mutant_nucleotide         4
# WT_codon                 54
# Mutant_codon             57
# CpG_site                  2
# Splice_site               5
# Context_coding_3         17
# WT_AA                    21
# Mutant_AA                21
# Effect                    8
# AGVGDClass                7
# SIFTClass                 2
# Polyphen2                 3
# TransactivationClass      4
# DNEclass                  3
# ProtDescription         244
# Hotspot                   2
# Domain_function           9
# Residue_function         15
# FamilyCase               50
# FamilyCase_group          6
# Sex                       2
# Germline_carrier          4
# Mode_of_inheritance       4
# Short_topo_combined      87
# dtype: int64

# %%
# Find correlations with the target and sort
correlations = df.corr()['Age_at_diagnosis'].sort_values()

# Display correlations
print('Most Positive Correlations:\n', correlations.tail(15))
print('\nMost Negative Correlations:\n', correlations.head(15))
# Out:
# Most Positive Correlations:
#  Generation                  -0.311825
# REVEL                       -0.100563
# cBioportalCount             -0.093932
# BayesDel                    -0.086488
# Short_topo_combined_count   -0.059012
# Ref_ID                       0.003699
# COSMIClink                   0.055529
# Dead                         0.057207
# CLINVARlink                  0.060734
# Generations_analyzed         0.226798
# Age                          0.957766
# Age_at_diagnosis             1.000000
# Name: Age_at_diagnosis, dtype: float64
#
# Most Negative Correlations:
#  Generation                  -0.311825
# REVEL                       -0.100563
# cBioportalCount             -0.093932
# BayesDel                    -0.086488
# Short_topo_combined_count   -0.059012
# Ref_ID                       0.003699
# COSMIClink                   0.055529
# Dead                         0.057207
# CLINVARlink                  0.060734
# Generations_analyzed         0.226798
# Age                          0.957766
# Age_at_diagnosis             1.000000
# Name: Age_at_diagnosis, dtype: float64

# %%
# caluclate the % of missing value
df.isnull().sum()/ len(df)
# Out:
# Family_code                  0.000000
# Country                      0.017792
# Population                   0.017792
# Region                       0.017792
# Development                  0.017792
# Class                        0.095803
# Generations_analyzed         0.114051
# WT_nucleotide                0.000000
# Mutant_nucleotide            0.135493
# WT_codon                     0.098084
# Mutant_codon                 0.186131
# CpG_site                     0.000000
# Splice_site                  0.000000
# Context_coding_3             0.000000
# WT_AA                        0.098084
# Mutant_AA                    0.186131
# Effect                       0.002281
# AGVGDClass                   0.294708
# SIFTClass                    0.270073
# Polyphen2                    0.296533
# REVEL                        0.296533
# BayesDel                     0.296533
# TransactivationClass         0.296533
# DNEclass                     0.391423
# ProtDescription              0.000000
# COSMIClink                   0.112226
# CLINVARlink                  0.223540
# cBioportalCount              0.000000
# Hotspot                      0.000000
# Domain_function              0.131387
# Residue_function             0.188412
# FamilyCase                   0.289234
# FamilyCase_group             0.289234
# Generation                   0.185675
# Sex                          0.062956
# Germline_carrier             0.432482
# Mode_of_inheritance          0.831204
# Dead                         0.000000
# Age                          0.715785
# Age_at_diagnosis             0.000000
# Ref_ID                       0.000000
# Short_topo_combined          0.000000
# Short_topo_combined_count    0.000000
# dtype: float64

# %%
# one-hot encoding of categorical variables
df_onehot = pd.get_dummies(df)
print(df.shape, df_onehot.shape)
# Out:
# (2192, 43) (2192, 1620)

# %%
# imputer for handling missing values
from sklearn.preprocessing import Imputer
fill_NaN = Imputer(strategy = 'median', axis=1)
imputed_df = pd.DataFrame(fill_NaN.fit_transform(df_onehot))
imputed_df.columns = df_onehot.columns
imputed_df.index = df_onehot.index
# Out:
# Generations_analyzed                             0.0
# REVEL                                            0.0
# BayesDel                                         0.0
# COSMIClink                                       0.0
# CLINVARlink                                      0.0
# cBioportalCount                                  0.0
# Generation                                       0.0
# Dead                                             0.0
# Age                                              0.0
# Age_at_diagnosis                                 0.0
# Ref_ID                                           0.0
# Short_topo_combined_count                        0.0
# Family_code_AGA08-1                              0.0
# Family_code_AKO16                                0.0
# Family_code_AND17-12                             0.0
# Family_code_AND17-25                             0.0
# Family_code_AND17-28                             0.0
# Family_code_AND17-35                             0.0
# Family_code_AND17-36                             0.0
# Family_code_AND17-49                             0.0
# Family_code_AND17-50                             0.0
# Family_code_AND17-53                             0.0
# Family_code_AND18-1                              0.0
# Family_code_ANE06                                0.0
# Family_code_ANG09                                0.0
# Family_code_ARC07-1039                           0.0
# Family_code_ARC07-1444                           0.0
# Family_code_ARC07-875                            0.0
# Family_code_ARC15-F1580                          0.0
# Family_code_ARC15-F1582                          0.0
#                                                 ...
# Short_topo_combined_NERVES                       0.0
# Short_topo_combined_NERVES;OVARY                 0.0
# Short_topo_combined_NERVES;SOFT TISSUES          0.0
# Short_topo_combined_OTHER DIGESTIVE ORG.         0.0
# Short_topo_combined_OTHER HEAD&NECK              0.0
# Short_topo_combined_OTHER MALE GEN. ORG.         0.0
# Short_topo_combined_OTHER SITES                  0.0
# Short_topo_combined_OVARY                        0.0
# Short_topo_combined_OVARY;SOFT TISSUES           0.0
# Short_topo_combined_PANCREAS                     0.0
# Short_topo_combined_PAROTID GLAND                0.0
# Short_topo_combined_PERITONEUM                   0.0
# Short_topo_combined_PLACENTA                     0.0
# Short_topo_combined_PROSTATE                     0.0
# Short_topo_combined_RECTUM                       0.0
# Short_topo_combined_RECTUM;UNKNOWN SITE          0.0
# Short_topo_combined_SINUSES                      0.0
# Short_topo_combined_SKIN                         0.0
# Short_topo_combined_SMALL INTESTINE              0.0
# Short_topo_combined_SOFT TISSUES                 0.0
# Short_topo_combined_SOFT TISSUES;UNKNOWN SITE    0.0
# Short_topo_combined_SPINAL CORD                  0.0
# Short_topo_combined_STOMACH                      0.0
# Short_topo_combined_TESTIS                       0.0
# Short_topo_combined_THYROID                      0.0
# Short_topo_combined_TONGUE (other)               0.0
# Short_topo_combined_UNKNOWN SITE                 0.0
# Short_topo_combined_URETER                       0.0
# Short_topo_combined_UTERUS                       0.0
# Short_topo_combined_VAGINA                       0.0
# Length: 1620, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

# Make the random forest classifier
random_forest = RandomForestClassifier(n_estimators = 100, random_state = 50, verbose = 1, n_jobs = -1)
# Train on the training data
random_forest.fit(imputed_df.loc[:, imputed_df.columns != 'Age_at_diagnosis'],imputed_df.loc[:, 'Age_at_diagnosis'])
# Out:
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.6s finished
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=50, verbose=1, warm_start=False)

# %%
# Extract feature importances
feature_importance_values = random_forest.feature_importances_
feature_importance_values
# Out:
# array([1.98979071e-02, 8.97602384e-03, 9.70905910e-03, ...,
#        2.32996246e-04, 2.05647247e-03, 4.55932968e-05])
