# %%
import pandas as pd
from numpy import loadtxt
from xgboost import XGBClassifier
from matplotlib import pyplot

# %%
# load data
fn = "LFS_clean.tsv"
df = pd.read_csv(fn,sep="\t")
df.head()
# Out:
#    Family_ID Family_code Country        Population    Region  \
# 0          4      Bard94     USA  Northern America  Americas
# 1          4      Bard94     USA  Northern America  Americas
# 2          4      Bard94     USA  Northern America  Americas
# 3          5       Bir16      UK   Northern Europe    Europe
# 4          5       Bir16      UK   Northern Europe    Europe
#
#               Development Class  Generations_analyzed Germline_mutation  \
# 0  More developed regions   LFL                   2.0              TP53
# 1  More developed regions   LFL                   2.0              TP53
# 2  More developed regions   LFL                   2.0              TP53
# 3  More developed regions   LFS                   2.0              TP53
# 4  More developed regions   LFS                   2.0              TP53
#
#    MUT_ID            ...             \
# 0    3259            ...
# 1    3259            ...
# 2    3259            ...
# 3    2821            ...
# 4    2821            ...
#
#                                       Topography       Short_topo  \
# 0  HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS  HEMATOP. SYSTEM
# 1                                   CERVIX UTERI     CERVIX UTERI
# 2                                  ADRENAL GLAND    ADRENAL GLAND
# 3                                         BREAST           BREAST
# 4                                  ADRENAL GLAND    ADRENAL GLAND
#
#                            Morphology Age_at_diagnosis  Ref_ID  \
# 0                       Leukemia, NOS              6.0       1
# 1                      Carcinoma, NOS             30.0       1
# 2  Adrenal cortical carcinoma (C74.0)              1.0       1
# 3                         Cancer, NOS             27.0       2
# 4  Adrenal cortical carcinoma (C74.0)              1.0       2
#
#            Other_infos p53mut_ID   Add_Info Short_topo_combined  \
# 0                  NaN         2  in ref 62     HEMATOP. SYSTEM
# 1                  NaN         2        NaN        CERVIX UTERI
# 2                  NaN         2        NaN       ADRENAL GLAND
# 3  updated from ref 86         3        NaN              BREAST
# 4  updated from ref 86         3        NaN       ADRENAL GLAND
#
#   Short_topo_combined_count
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
#
# [5 rows x 66 columns]
